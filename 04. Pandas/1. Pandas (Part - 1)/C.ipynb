# %%
# 3. Introduction to Pandas

# %%
import pandas as pd

# %%
info = {
    "Name" : ["Cipher Mind", "Cipher", "Mind"],
    "CGPA" : [9.8, 9.2, 9.9]
}

print(info)

print(type(info))

# %%
df = pd.DataFrame(info)

print(df)

print(type(df))

# %%
df
