# %%
# 7. Pandas with csv & json data - given files

# %%
import pandas as pd

# %%
df = pd.read_csv("employee_data.csv")
print(type(df))
df

# %%
df = pd.read_json("employee_data.json")
print(type(df))
df
