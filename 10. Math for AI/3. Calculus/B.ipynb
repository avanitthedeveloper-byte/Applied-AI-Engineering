# %%
# 2. Functions

# %%
import matplotlib.pyplot as plt

import numpy as np

# %%
x = np.linspace(0, 100, 100)
y = np.sqrt(x)

plt.plot(y, label = "y = √x")
plt.xlabel("x")
plt.ylabel("y = √x")
plt.legend()
plt.title("Graph of y = √x")
plt.grid()
