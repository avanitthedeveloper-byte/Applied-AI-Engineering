# %%
# 3. Homework Problem

# %%
import requests

import pandas as pd

# %%
URL = "https://api.cdnjs.com/libraries/jquery"

# %%
res = requests.get(URL)

# %%
res
# Out:
# <Response [200]>

# %%
json_data = res.json()

json_data
# Out:
# {'name': 'jquery',
#  'latest': 'https://cdnjs.cloudflare.com/ajax/libs/jquery/3.7.1/jquery.min.js',
#  'sri': 'sha512-v2CJ7UaYy4JwqLDIrZUI/4hqeoQieOmAZNXBeQyjo21dadnwR+8ZaIJVT8EE2iyI61OV8e6M8PP2/4hpQINQ/g==',
#  'description': 'JavaScript library for DOM operations',
#  'keywords': ['jquery', 'library', 'ajax', 'framework', 'toolkit', 'popular'],
#  'version': '3.7.1',
#  'filename': 'jquery.min.js',
#  'homepage': 'http://jquery.com/',
#  'license': 'MIT',
#  'author': 'jQuery Foundation and other contributors (https://github.com/jquery/jquery/blob/master/AUTHORS.txt)',
#  'repository': {'type': 'git', 'url': 'https://github.com/jquery/jquery.git'},
#  'autoupdate': {'source': 'npm', 'target': 'jquery'},
#  'versions': ['4.0.0-rc.1',
#   '4.0.0-beta.2',
#   '4.0.0-beta',
#   '3.7.1',
#   '3.7.0',
#   '3.6.4',
#   '3.6.3',
#   '3.6.2',
#   '3.6.1',
#   '3.6.0',
#   '3.5.1',
#   '3.5.0',
#   '3.4.1',
#   '3.4.0',
#   '3.3.1',
#   '3.3.0',
#   '3.2.1',
#   '3.2.0',
#   '3.1.1',
# ...

# %%
df = pd.json_normalize(json_data)

df
# Out:
#      name                                             latest  \
# 0  jquery  https://cdnjs.cloudflare.com/ajax/libs/jquery/...
#
#                                                  sri  \
# 0  sha512-v2CJ7UaYy4JwqLDIrZUI/4hqeoQieOmAZNXBeQy...
#
#                              description  \
# 0  JavaScript library for DOM operations
#
#                                             keywords version       filename  \
# 0  [jquery, library, ajax, framework, toolkit, po...   3.7.1  jquery.min.js
#
#              homepage license  \
# 0  http://jquery.com/     MIT
#
#                                               author  \
# 0  jQuery Foundation and other contributors (http...
#
#                                             versions  \
# 0  [4.0.0-rc.1, 4.0.0-beta.2, 4.0.0-beta, 3.7.1, ...
#
#                                               assets repository.type  \
# 0  [{'version': '3.7.1', 'files': ['jquery.js', '...             git
#
# ...
