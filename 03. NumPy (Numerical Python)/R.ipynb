# %%
# 18. Other Math Functions

# %%
import numpy as np

# %%
arr = np.array([1, 3, 5, 9, -6, 2, 7, 3, 9])

# %%
print(arr)
print(f"Unique(): {np.unique(arr)}")
print(f"Sort(): {np.sort(arr)}")
print(f"Abs(): {np.abs(arr)}")
# Out:
# [1 3 5 7 3 9]
# Unique(): [1 3 5 7 9]
# Sort(): [1 3 3 5 7 9]
# Abs(): [1 3 5 7 3 9]
