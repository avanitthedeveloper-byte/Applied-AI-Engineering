# %%
# 9. Bar Charts

# %%
import matplotlib.pyplot as plt

# %%
movie = [
    "The Dark Night", 
    "The Heart Locker", 
    "The King's Speech", 
    "The Artist", 
    "Argo"]

year = [2008, 2009, 2010, 2011, 2012]

revenue = [1005, 170, 427, 232, 829]

# %%
plt.bar(year, revenue, color = "green", label = "Revenue")

plt.xlabel("Year")
plt.ylabel("Revenue (in $M)")
plt.legend()

plt.title("Oscar Movie Revenue")
