# %%
# 3. Introduction to Pandas

# %%
import pandas as pd

# %%
info = {
    "Name" : ["Cipher Mind", "Cipher", "Mind"],
    "CGPA" : [9.8, 9.2, 9.9]
}

print(info)

print(type(info))
# Out:
# {'Name': ['Cipher Mind', 'Cipher', 'Mind'], 'CGPA': [9.8, 9.2, 9.9]}
# <class 'dict'>

# %%
df = pd.DataFrame(info)

print(df)

print(type(df))
# Out:
#           Name  CGPA
# 0  Cipher Mind   9.8
# 1       Cipher   9.2
# 2         Mind   9.9
# <class 'pandas.core.frame.DataFrame'>

# %%
df
# Out:
#           Name  CGPA
# 0  Cipher Mind   9.8
# 1       Cipher   9.2
# 2         Mind   9.9
