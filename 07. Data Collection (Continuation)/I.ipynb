# %%
# 9. Additional Techniques

# %%
import requests

# %%
URL = "https://brownspace.co.in/"

# %%
headers = {
    "User-Agent": "Mozilla/5.0"
}

# %%
res = requests.get(URL, headers = headers)
print(res.text)
