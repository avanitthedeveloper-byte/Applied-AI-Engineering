# %%
# 3. Set up JSON data

# %%
import json

# %%
# load the data
def load_data(file_name):
    with open(file_name, "r") as f:
        data = json.load(f)
    return data

# %%
data = load_data("store_data.json")
print(data)
