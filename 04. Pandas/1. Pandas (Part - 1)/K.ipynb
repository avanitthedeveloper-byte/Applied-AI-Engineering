# %%
# 11. Filtering Data

# %%
import pandas as pd

# %%
df = pd.read_csv("globalAirQuality.csv")

df
# Out:
#                         timestamp country      city  latitude  longitude  \
# 0      2025-11-04 18:25:17.554219      US  New York    40.713    -74.006
# 1      2025-11-04 19:25:17.554219      US  New York    40.713    -74.006
# 2      2025-11-04 20:25:17.554219      US  New York    40.713    -74.006
# 3      2025-11-04 21:25:17.554219      US  New York    40.713    -74.006
# 4      2025-11-04 22:25:17.554219      US  New York    40.713    -74.006
# ...                           ...     ...       ...       ...        ...
# 17995  2025-11-19 13:25:17.554219      CH    Zurich    47.377      8.542
# 17996  2025-11-19 14:25:17.554219      CH    Zurich    47.377      8.542
# 17997  2025-11-19 15:25:17.554219      CH    Zurich    47.377      8.542
# 17998  2025-11-19 16:25:17.554219      CH    Zurich    47.377      8.542
# 17999  2025-11-19 17:25:17.554219      CH    Zurich    47.377      8.542
#
#          pm25     pm10     no2    so2      o3     co  aqi  temperature  \
# ...

# %%
# Filtering of Data

df[df["aqi"] > 175]
# Out:
#                         timestamp country         city  latitude  longitude  \
# 112    2025-11-09 10:25:17.554219      US     New York    40.713    -74.006
# 194    2025-11-12 20:25:17.554219      US     New York    40.713    -74.006
# 320    2025-11-18 02:25:17.554219      US     New York    40.713    -74.006
# 370    2025-11-05 04:25:17.554219      US  Los Angeles    34.052   -118.244
# 589    2025-11-14 07:25:17.554219      US  Los Angeles    34.052   -118.244
# ...                           ...     ...          ...       ...        ...
# 17767  2025-11-10 01:25:17.554219      CH       Zurich    47.377      8.542
# 17774  2025-11-10 08:25:17.554219      CH       Zurich    47.377      8.542
# 17815  2025-11-12 01:25:17.554219      CH       Zurich    47.377      8.542
# 17885  2025-11-14 23:25:17.554219      CH       Zurich    47.377      8.542
# 17886  2025-11-15 00:25:17.554219      CH       Zurich    47.377      8.542
#
# ...

# %%
df[(df["aqi"] > 175) & (df["country"] == "IN")]

# df[df["aqi"] > 200]
# Out:
#                        timestamp country     city  latitude  longitude  \
# 6641  2025-11-11 11:25:17.554219      IN   Mumbai    19.076     72.878
# 6747  2025-11-15 21:25:17.554219      IN   Mumbai    19.076     72.878
# 6783  2025-11-17 09:25:17.554219      IN   Mumbai    19.076     72.878
# 6954  2025-11-09 12:25:17.554219      IN    Delhi    28.704     77.102
# 7024  2025-11-12 10:25:17.554219      IN    Delhi    28.704     77.102
# 7045  2025-11-13 07:25:17.554219      IN    Delhi    28.704     77.102
# 7178  2025-11-18 20:25:17.554219      IN    Delhi    28.704     77.102
# 7678  2025-11-09 16:25:17.554219      IN  Kolkata    22.573     88.364
# 7685  2025-11-09 23:25:17.554219      IN  Kolkata    22.573     88.364
# 8175  2025-11-15 09:25:17.554219      IN  Chennai    13.083     80.271
#
#         pm25    pm10     no2     so2      o3     co  aqi  temperature  \
# 6641  37.509  80.830  73.015   6.403  60.263  0.890  182       12.845
# ...

# %%
df[df["country"] == "IN"]["city"]
# Out:
# 6480     Mumbai
# 6481     Mumbai
# 6482     Mumbai
# 6483     Mumbai
# 6484     Mumbai
#          ...
# 8275    Chennai
# 8276    Chennai
# 8277    Chennai
# 8278    Chennai
# 8279    Chennai
# Name: city, Length: 1800, dtype: object

# %%
df[(df["aqi"]>185) & (df["country"] == "IN")][["temperature", "city", "temperature"]]
# Out:
#       temperature    city  temperature
# 6747       32.153  Mumbai       32.153
# 6783       37.271  Mumbai       37.271
# 6954       10.302   Delhi       10.302
# 7024       34.274   Delhi       34.274
