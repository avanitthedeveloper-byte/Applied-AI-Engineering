# %%
# 3. Homework Problem

# %%
import requests

import pandas as pd

# %%
URL = "https://api.cdnjs.com/libraries/jquery"

# %%
res = requests.get(URL)

# %%
res

# %%
json_data = res.json()

json_data

# %%
df = pd.json_normalize(json_data)

df
