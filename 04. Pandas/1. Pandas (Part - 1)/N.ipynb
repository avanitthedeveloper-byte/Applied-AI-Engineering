# %%
# 14. Data Cleaning (Handle Duplicate)

# %%
import pandas as pd

# %%
df = pd.read_csv("raw_data.csv")

df

# %%
df.isnull() # or 
df.isna()

# %%
df.isnull().sum()

# %%
df.dropna()

# df.dropna(axis = 1)

# %%
df.fillna(0)

# %%
cleaned_data = df.copy()
cleaned_data

# %%
cleaned_data.fillna(0)

age_mean = cleaned_data["age"].mean()

cleaned_data["age"] = cleaned_data["age"].fillna(age_mean)

cleaned_data

# %%
df.ffill()

# %%
df.bfill()

# %%
df.duplicated()

# %%
df.drop_duplicates()

# %%
df.drop_duplicates(inplace=True)

df

# %%
df
